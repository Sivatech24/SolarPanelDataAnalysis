# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import warnings

# %%
# Load datasets
dataset_1 = pd.read_csv('/Users/tech/Documents/Jupyter Notebook/DataSet/SolarPower/Plant_1_Generation_Data.csv')
dataset_2 = pd.read_csv('/Users/tech/Documents/Jupyter Notebook/DataSet/SolarPower/Plant_2_Generation_Data.csv')

# %%
dataset_1['DATE_TIME'] = pd.to_datetime(dataset_1['DATE_TIME'])
dataset_2['DATE_TIME'] = pd.to_datetime(dataset_2['DATE_TIME'])
# Out:
# C:\Users\tech\AppData\Local\Temp\ipykernel_5532\2793333325.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   dataset_1['DATE_TIME'] = pd.to_datetime(dataset_1['DATE_TIME'])

# %%
dataset_1.fillna(method='ffill', inplace=True)
dataset_2.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\tech\AppData\Local\Temp\ipykernel_5532\1540329266.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset_1.fillna(method='ffill', inplace=True)
# C:\Users\tech\AppData\Local\Temp\ipykernel_5532\1540329266.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset_2.fillna(method='ffill', inplace=True)

# %%
threshold = 100  # Adjust as needed
dataset_1['target'] = (dataset_1['AC_POWER'] < threshold).astype(int)
dataset_2['target'] = (dataset_2['AC_POWER'] < threshold).astype(int)

# %%
features = ['DC_POWER', 'DAILY_YIELD', 'TOTAL_YIELD']  # Select relevant features
X1 = dataset_1[features]
y1 = dataset_1['target']
X2 = dataset_2[features]
y2 = dataset_2['target']

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=42)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, random_state=42)

# %%
model1 = LogisticRegression(max_iter=1000)
model1.fit(X_train1, y_train1)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model2 = LogisticRegression(max_iter=1000)
model2.fit(X_train2, y_train2)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred1 = model1.predict(X_test1)
y_pred2 = model2.predict(X_test2)

# %%
print("Dataset 1 Evaluation:")
print("Accuracy:", accuracy_score(y_test1, y_pred1))
print(classification_report(y_test1, y_pred1))

print("Dataset 2 Evaluation:")
print("Accuracy:", accuracy_score(y_test2, y_pred2))
print(classification_report(y_test2, y_pred2))
# Out:
# Dataset 1 Evaluation:
# Accuracy: 0.9968013957545798
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6362
#            1       1.00      1.00      1.00      7394
#
#     accuracy                           1.00     13756
#    macro avg       1.00      1.00      1.00     13756
# weighted avg       1.00      1.00      1.00     13756
#
# Dataset 2 Evaluation:
# Accuracy: 0.9657311669128508
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      5242
#            1       0.99      0.96      0.97      8298
#
#     accuracy                           0.97     13540
#    macro avg       0.96      0.97      0.96     13540
# weighted avg       0.97      0.97      0.97     13540
